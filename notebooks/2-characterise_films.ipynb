# %%
# Convenient jupyter setup
# %load_ext autoreload
# %autoreload 2

# %%
from skimage.io import imread
import matplotlib.pyplot as plt
import numpy as np
import math

from src.processing.txt_loading import txt_to_list
from src.processing.characterise_biofilm import characterise_both_biofilm_images, characterise_biofilm_image
from src.processing.constants import BUCKLING_PATH, EDGE_TRACKING_PATH
from src.processing.labelled_regions import label_regions, characterise_regions

# %% [markdown]
# 1. Read stacks

# %%
bright_img = imread(str(BUCKLING_PATH / "200920_normallight_nobg_edges_gaussblur_enhance_inverted.tif"))
bio_img = imread(str(BUCKLING_PATH / "200920_biolight_nobg_nooutliers_despeckle_enhance.tif"))

# %%
stress_img = imread(str(BUCKLING_PATH / "stress_mag.png"))

# %%
plt.figure(figsize=(10,10))
plt.imshow(stress_img)

# %%
stress_img = np.array[stress_img[i][0], for i in stress_img]
# Out:
#   File "<ipython-input-12-01bcc967ace5>", line 1
#     stress_img = np.array[stress_img[i][0], for i in stress_img]
#                                               ^
# SyntaxError: invalid syntax

# %%
labelled_image= label_regions(stress_img, 0, threshold_high = 255, plot= True)

# %%
 characterise_regions(image, labelled_image, lower_contour_bound = 0, upper_contour_bound = 1000000, plot = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-3e902e08f0fa> in <module>
# ----> 1 characterise_regions(image, labelled_image, lower_contour_bound = 0, upper_contour_bound = 1000000, plot = True)
#
# NameError: name 'image' is not defined

# %%
characterise_biofilm_image(stress_img, None, 0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-6-6ef6e63163e6> in <module>
# ----> 1 characterise_biofilm_image(stress_img, None, 0)
#
# ~/projects/biofilm/Biofilms/src/processing/characterise_biofilm.py in characterise_biofilm_image(stack, slice_no, type, label_threshold)
#      23         film = 'Brightfield'
#      24         img = label_regions(slice, label_threshold)
# ---> 25         lit_area, average_area = characterise_regions(slice, img, 20, plot = True)
#      26         timestamps, radii, x_centres, y_centres = txt_to_list('200920_normallight_fitted_circle_position_data.txt')
#      27
#
# ~/projects/biofilm/Biofilms/src/processing/labelled_regions.py in characterise_regions(image, labelled_image, lower_contour_bound, upper_contour_bound, plot)
#      73         #    plt.plot(coords[:,1],coords[:,0],'r.')
#      74         #   print(prop.area)
# ---> 75     average_area = sum(area_list) / len(area_list)
#      76     if plot == True:
#      77         plt.imshow(image, cmap='Reds')
#
# ZeroDivisionError: division by zero

# %%
timestamps_b, radii_b, x_center_b, y_center_b = txt_to_list(str(EDGE_TRACKING_PATH/'200920_biolight_fitted_circle_position_data.txt'))

# %% [markdown]
# 2. Characterise each image

# %%
slice =

# %%
characterise_biofilm_image(bio_img, 130, 1)

# %%
characterise_biofilm_image(bright_img, int(slice* 1.403726708), 0)
# Out:
# Brightfield image, slice 210/452
# Timestamp: 3.5
# Total lit area: 117392
# Fraction of biofilm lit: 0.20352831191917675
# Average area of lit region: 365.7071651090343
# Biofilm radius: 428.481325925969

# %% [markdown]
# Plot both labelled regions

# %%
characterise_both_biofilm_images(bright_img, bio_img, slice)
